# %%
# %%bash
# rm -r sample_data

# %% [markdown]
# Get fasta files from web

# %%
# %%bash
# wget -nv -O IGHJ_Mouse.fa 'https://drive.google.com/uc?export=download&id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO'
# wget -nv -O IGHJ_Human.fa 'https://drive.google.com/uc?export=download&id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz'
# wget -nv -O IGHJ_Zebrafish.fa 'https://drive.google.com/uc?export=download&id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak'
# Out:
# 2024-06-26 10:13:52 URL:https://drive.usercontent.google.com/download?id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO&export=download [1178/1178] -> "IGHJ_Mouse.fa" [1]
# 2024-06-26 10:13:53 URL:https://drive.usercontent.google.com/download?id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz&export=download [2639/2639] -> "IGHJ_Human.fa" [1]
# 2024-06-26 10:13:54 URL:https://drive.usercontent.google.com/download?id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak&export=download [1034/1034] -> "IGHJ_Zebrafish.fa" [1]

# %%
# %%bash
# > headers.txt
#
# for file in *.fa; do
#   if [ -e "$file" ]; then
#     grep '^>' "$file" >> headers.txt
#   fi
# done

# %%
# %%bash
#
# > lengths.txt
#
# for file in *.fa; do
#   if [ -e "$file" ]; then
#     grep '^>' "$file" >> lengths.txt
#     total_length=$(grep -v '^>' "$file" | tr -d '\n' | wc -c)
#     echo "$total_length" >> lengths.txt
#   fi
# done
