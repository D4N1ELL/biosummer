# %% [markdown]
# **Select the O antigen from this list.**

# %%
bloodAntigens = ['A', 'B', 'O']
bloodAntigens[2]
# Out:
# 'O'

# %% [markdown]
# The problem here is indexing out of bounds and incorrect data attribution. We declare the equal ov the value with one = instead of ==. Also indexing starts at 0 and we have 3 positions, therefore the maximum value that can be called here is 2.

# %% [markdown]
# **Lookup the O-compatible plasma types from this dictionary.**

# %%
bloodTypeCompatibilities = { 'A':['A', 'AB'], 'B':['B', 'AB'], 'AB':['AB'] , 'O': ['A', 'B', 'AB', 'O']}
bloodTypeCompatibilities['A']
# Out:
# ['A', 'AB']

# %% [markdown]
# Declare data types as strings using '' and print using 'A' instead of 0

# %% [markdown]
# **Access the beginning of the sample name column in the following DataFrame.**

# %%
import pandas as pd
columns = {"sampleName": ['cell1','cell2','cell3','cell4'], 'Treatment': ['Case', 'Control', 'Control', 'Case']}
df = pd.DataFrame(columns)

df["sampleName"].head()
# Out:
# 0    cell1
# 1    cell2
# 2    cell3
# 3    cell4
# Name: sampleName, dtype: object

# %% [markdown]
# Call dataframe with df instead of DataFrame and also syntax error in `sampleName`. We will replace with "" to define as string

# %% [markdown]
# **Save the Superfamily column from the DataFrame downloaded below.**

# %%
import pandas as pd
antBrainCellsDF = pd.read_csv('https://zenodo.org/record/4579911/files/00_RKG_MS_WG_RawCCData.csv?download=1')
superfamilyColumn = antBrainCellsDF['Superfamily']
superfamilyColumn.to_csv('superfamilyColumn.csv')

# %% [markdown]
# The URL for reading the CSV should be a string. Typo in Superfami1y, should be Superfamily. To save a DataFrame to a CSV file, name should be specified as .csv  between strings.
