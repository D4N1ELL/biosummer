# %%
# %%bash
# rm -r sample_data
# mkdir Repository
# cd Repository
# touch README.txt
# mkdir summarydata
# mkdir notebook
# mkdir figure
# mkdir multipanel
# cd summarydata
# touch README.txt
# touch Figure_1a_data.csv
# touch Figure_1b_data.csv
# touch Figure_2a_data.csv
# touch Figure_2b_data.csv
# touch Figure_2c_data.csv
# cd ..
# cd notebook
# touch README.txt
# touch Figure1.ipynb
# touch Figure2.ipynb
# cd ..
# cd figure
# touch README.txt
# touch Figure1a.pdf
# touch Figure1b.pdf
# touch Figure2a.pdf
# touch Figure2b.pdf
# touch Figure2c.pdf
# cd ..
# cd multipanel
# touch README.txt
# touch Figure1.ai
# touch Figure2.ai
